# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-70992a60-955e-4eb4-9cb5-0154fe7efec1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-70992a60-955e-4eb4-9cb5-0154fe7efec1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Hermione Granger.csv to Hermione Granger.csv

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
from fastai.vision import *
from fastai.metrics import error_rate
import warnings
warnings.filterwarnings("ignore")
img_counter = []
img_counter.append(10)

# %%
folder = 'Hermione Granger'
url_file = 'Hermione Granger.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)
download_images(url_file,dest,max_pics=10000)

# %%
classes = ['Hermoine Granger']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-39e420da-a820-4ee9-92c6-86d1bdafb989" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-39e420da-a820-4ee9-92c6-86d1bdafb989">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Harry Potter.csv to Harry Potter.csv

# %%
folder = 'Harry Potter'
url_file = 'Harry Potter.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)
download_images(url_file,dest,max_pics=10000)

# %%
classes.append('Harry')

# %%
for i in range(0,len(classes)):
  print(classes[i])
# Out:
# Hermoine Granger
# ['Harry']
# Harry

# %%
for i in range(0,len(classes)):
  print (classes[i])
# Out:
# Hermoine Granger
# Harry

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28b4887f-e804-4e93-9383-372ffad9a474" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28b4887f-e804-4e93-9383-372ffad9a474">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Albus Dumbledore.csv to Albus Dumbledore.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a21e0270-adde-4415-8c3f-1bebb6483528" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a21e0270-adde-4415-8c3f-1bebb6483528">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Severus Snape.csv to Severus Snape.csv

# %%
folder = 'Albus Dumbledore'
url_file = 'Albus Dumbledore.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)
download_images(url_file,dest,max_pics=10000)

# %%
folder = 'Draco Malfoy'
url_file = 'Draco Malfoy .csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)
download_images(url_file,dest,max_pics=10000)

# %%
folder = 'Lord Voldemort'
url_file = 'Lord Voldemort.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)
download_images(url_file,dest,max_pics=10000)

# %%
folder = 'Ron Weasley'
url_file = 'Ron Weasley.csv'
path = Path('my_data')
dest = path/folder
dest.mkdir(parents = True, exist_ok = True)
download_images(url_file,dest,max_pics=10000)

# %%
classes.append('Albus Dumbledore' , 'Draco Malfoy','Hermione Granger','Lord Voldemort','Ron Weasley')

# %%
classes.append({'Albus Dumbledore' , 'Draco Malfoy','Hermione Granger','Lord Voldemort','Ron Weasley'})

# %%
for i in range (0,len(classes)):
  print(classes[i])
# Out:
# Hermoine Granger
# Harry
# {'Draco Malfoy', 'Albus Dumbledore', 'Hermione Granger', 'Lord Voldemort', 'Ron Weasley'}

# %%
del classes[2]
classes.append('Albus Dumbledore')
classes.append('Draco Malfoy')
classes.append('Ron Weasley')
classes.append('Lord Voldemort')

# %%
for i in range(0,len(classes)):
  print (classes[i])
# Out:
# Hermoine Granger
# Harry
# Albus Dumbledore
# Draco Malfoy
# Ron Weasley
# Lord Voldemort

# %%
for i in classes:
  print(i)
  verify_images(path/i,delete=True,max_size=500)
# Out:
# Hermoine Granger
# Harry
# Albus Dumbledore
# Draco Malfoy
# Ron Weasley
# Lord Voldemort

# %%
data = ImageDataBunch.from_folder(path,train=".",valid_pct=0.2,ds_tfms = get_transforms(),size = 224).normalize(imagenet_stats)

# %%
data.classes
# Out:
# ['Albus Dumbledore',
#  'Draco Malfoy',
#  'Harry Potter',
#  'Hermione Granger',
#  'Lord Voldemort',
#  'Ron Weasley']

# %%
data.show_batch(rows=3, figsize=(10,12))

# %%
kaggle datasets download -d vaibhavagarwal14/harry-potter
